# %%
# 1. Install core dependencies
# !pip install -q torch==2.4.1 torchvision --extra-index-url https://download.pytorch.org/whl/cu121
# !pip install -U "transformers<4.46.0" "peft>=0.12.0" "accelerate>=0.33.0"

# 2. Clone and setup OmniGen
# !git clone https://github.com/VectorSpaceLab/OmniGen.git
# %cd /content/OmniGen
# !sed -i 's/accelerate==0.26.1/accelerate>=0.26.1/' setup.py
# !pip install -e .

# 3. FORCE FIX: Downgrade diffusers AFTER OmniGen installation to override its requirements
# !pip install -U "diffusers==0.30.0"

# 4. Install UI dependencies
# !pip install -q gradio spaces

print("\n✅ Setup finished. Please restart the session if you still see import errors, then run the UI cell.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 MB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 89.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 61.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 116.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 723.9 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 14.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 121.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 107.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 117.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.10.0+cu128 requires torch==2.10.0, but you have torch 2.4.1+cu121 which is incompatible.
# Collecting transformers<4.46.0
#   Downloading transformers-4.45.2-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: peft>=0.12.0 in /usr/local/lib/python3.12/dist-packages (0.19.1)
# Requirement already satisfied: accelerate>=0.33.0 in /usr/local/lib/python3.12/dist-packages (1.13.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers<4.46.0) (3.29.0)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers<4.46.0)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers<4.46.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers<4.46.0) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers<4.46.0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<4.46.0) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers<4.46.0) (2.32.4)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers<4.46.0) (0.7.0)
# Collecting tokenizers<0.21,>=0.20 (from transformers<4.46.0)
#   Downloading tokenizers-0.20.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers<4.46.0) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft>=0.12.0) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft>=0.12.0) (2.4.1+cu121)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers<4.46.0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers<4.46.0) (1.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers<4.46.0) (4.15.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0) (75.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft>=0.12.0) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->peft>=0.12.0) (12.8.93)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.46.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.46.0) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.46.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.46.0) (2026.4.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft>=0.12.0) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch>=1.13.0->peft>=0.12.0) (1.3.0)
# Downloading transformers-4.45.2-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 118.8 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 51.7 MB/s eta 0:00:00
# Downloading tokenizers-0.20.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 121.1 MB/s eta 0:00:00
# Installing collected packages: huggingface-hub, tokenizers, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.11.0
#     Uninstalling huggingface_hub-1.11.0:
#       Successfully uninstalled huggingface_hub-1.11.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# Successfully installed huggingface-hub-0.36.2 tokenizers-0.20.3 transformers-4.45.2
# Cloning into 'OmniGen'...
# remote: Enumerating objects: 711, done.
# remote: Counting objects: 100% (237/237), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 711 (delta 170), reused 154 (delta 154), pack-reused 474 (from 1)
# Receiving objects: 100% (711/711), 426.28 MiB | 16.38 MiB/s, done.
# Resolving deltas: 100% (340/340), done.
# /content/OmniGen
# Obtaining file:///content/OmniGen
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch<2.5 in /usr/local/lib/python3.12/dist-packages (from OmniGen==1.0.3) (2.4.1+cu121)
# Requirement already satisfied: transformers>=4.45.2 in /usr/local/lib/python3.12/dist-packages (from OmniGen==1.0.3) (4.45.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from OmniGen==1.0.3) (4.0.0)
# Requirement already satisfied: accelerate>=0.26.1 in /usr/local/lib/python3.12/dist-packages (from OmniGen==1.0.3) (1.13.0)
# Requirement already satisfied: diffusers>=0.30.3 in /usr/local/lib/python3.12/dist-packages (from OmniGen==1.0.3) (0.37.1)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from OmniGen==1.0.3) (1.0.26)
# Requirement already satisfied: peft>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from OmniGen==1.0.3) (0.19.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from OmniGen==1.0.3) (0.7.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from OmniGen==1.0.3) (75.2.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.26.1->OmniGen==1.0.3) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.26.1->OmniGen==1.0.3) (26.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.26.1->OmniGen==1.0.3) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.26.1->OmniGen==1.0.3) (6.0.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.26.1->OmniGen==1.0.3) (0.36.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from diffusers>=0.30.3->OmniGen==1.0.3) (8.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers>=0.30.3->OmniGen==1.0.3) (3.29.0)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from diffusers>=0.30.3->OmniGen==1.0.3) (0.28.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers>=0.30.3->OmniGen==1.0.3) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers>=0.30.3->OmniGen==1.0.3) (2.32.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers>=0.30.3->OmniGen==1.0.3) (11.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from peft>=0.9.0->OmniGen==1.0.3) (4.67.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (4.15.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.5->OmniGen==1.0.3) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<2.5->OmniGen==1.0.3) (12.8.93)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.45.2->OmniGen==1.0.3) (0.20.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->OmniGen==1.0.3) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->OmniGen==1.0.3) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets->OmniGen==1.0.3) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->OmniGen==1.0.3) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets->OmniGen==1.0.3) (0.70.16)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm->OmniGen==1.0.3) (0.19.1+cu121)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->OmniGen==1.0.3) (3.13.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers>=0.30.3->OmniGen==1.0.3) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers>=0.30.3->OmniGen==1.0.3) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers>=0.30.3->OmniGen==1.0.3) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->diffusers>=0.30.3->OmniGen==1.0.3) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->diffusers>=0.30.3->OmniGen==1.0.3) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.1->OmniGen==1.0.3) (1.4.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers>=0.30.3->OmniGen==1.0.3) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers>=0.30.3->OmniGen==1.0.3) (2.5.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->diffusers>=0.30.3->OmniGen==1.0.3) (3.23.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<2.5->OmniGen==1.0.3) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->OmniGen==1.0.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->OmniGen==1.0.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets->OmniGen==1.0.3) (2026.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch<2.5->OmniGen==1.0.3) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->OmniGen==1.0.3) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->OmniGen==1.0.3) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->OmniGen==1.0.3) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->OmniGen==1.0.3) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->OmniGen==1.0.3) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->OmniGen==1.0.3) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->OmniGen==1.0.3) (1.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->OmniGen==1.0.3) (1.17.0)
# Installing collected packages: OmniGen
#   Running setup.py develop for OmniGen
# Successfully installed OmniGen-1.0.3
# Collecting diffusers==0.30.0
#   Downloading diffusers-0.30.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from diffusers==0.30.0) (8.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from diffusers==0.30.0) (3.29.0)
# Requirement already satisfied: huggingface-hub>=0.23.2 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.30.0) (0.36.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from diffusers==0.30.0) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.30.0) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from diffusers==0.30.0) (2.32.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from diffusers==0.30.0) (0.7.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from diffusers==0.30.0) (11.3.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.2->diffusers==0.30.0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.2->diffusers==0.30.0) (1.4.3)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.2->diffusers==0.30.0) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.2->diffusers==0.30.0) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.2->diffusers==0.30.0) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.23.2->diffusers==0.30.0) (4.15.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->diffusers==0.30.0) (3.23.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.30.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.30.0) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.30.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->diffusers==0.30.0) (2026.4.22)
# Downloading diffusers-0.30.0-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 98.1 MB/s eta 0:00:00
# Installing collected packages: diffusers
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.37.1
#     Uninstalling diffusers-0.37.1:
#       Successfully uninstalled diffusers-0.37.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# omnigen 1.0.3 requires diffusers>=0.30.3, but you have diffusers 0.30.0 which is incompatible.
# Successfully installed diffusers-0.30.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.1/108.1 kB 8.2 MB/s eta 0:00:00
#
# ✅ Setup finished. Please restart the session if you still see import errors, then run the UI cell.

# %%
import gradio as gr
from OmniGen import OmniGenPipeline

# ============================================================
# LOAD MODEL
# ============================================================
print("⏳ Đang load OmniGen-v1...")
# Removed 'offload_model=True' as it is no longer a valid argument
pipe = OmniGenPipeline.from_pretrained(
    "Shitao/OmniGen-v1",
)
# Manually move to GPU to ensure it uses CUDA
pipe.to("cuda")
print("✅ OmniGen-v1 đã sẵn sàng!")

# ============================================================
# GRADIO INTERFACE
# ============================================================
def generate_image(
    prompt,
    input_images,
    height,
    width,
    guidance_scale,
    img_guidance_scale,
    seed,
    max_input_image_size,
):
    """Tạo/chỉnh sửa ảnh bằng OmniGen"""
    # Xử lý input images
    img_list = []
    if input_images:
        for img in input_images:
            if isinstance(img, dict):
                img_list.append(img["path"])
            else:
                img_list.append(img)

    # Kiểm tra placeholder
    placeholder_count = prompt.count("<|image_")
    if len(img_list) == 0 and placeholder_count > 0:
        return None, "❌ Bạn có placeholder ảnh nhưng chưa upload ảnh!"
    if len(img_list) > 0 and placeholder_count == 0:
        # Auto thêm placeholder nếu thiếu
        for i in range(len(img_list)):
            prompt += f" <img><|image_{i+1}|></img>"

    try:
        images = pipe(
            prompt=prompt,
            input_images=img_list if img_list else None,
            height=int(height),
            width=int(width),
            guidance_scale=guidance_scale,
            img_guidance_scale=img_guidance_scale,
            seed=int(seed),
            max_input_image_size=int(max_input_image_size),
            separate_cfg_infer=True,  # Tiết kiệm VRAM trên T4
            use_kv_cache=False,
        )
        return images[0], "✅ Thành công!"
    except Exception as e:
        return None, f"❌ Lỗi: {str(e)}"


# Giao diện
with gr.Blocks(
    title="🎨 OmniGen - Uncensored AI Image Editor",
    theme=gr.themes.Soft(primary_hue="purple"),
) as demo:

    gr.Markdown("""
    # 🎨 OmniGen — Uncensored AI Image Editor
    Model thống nhất: Text→Image • Image Editing • Subject-Driven • Identity-Preserving

    **Cách dùng:** Gõ lệnh mô tả. Nếu muốn chỉnh sửa ảnh, upload ảnh và dùng `<img><|image_1|></img>` để tham chiếu ảnh trong prompt.
    """)

    with gr.Row():
        with gr.Column(scale=1):
            prompt = gr.Textbox(
                label="✍️ Prompt",
                placeholder="VD: A curly-haired man in a red shirt is drinking tea.\n\nVới ảnh: A man in a black shirt is reading a book. The man is the right man in <img><|image_1|></img>.",
                lines=4,
            )
            input_images = gr.File(
                label="📸 Ảnh đầu vào (có thể nhiều ảnh)",
                file_count="multiple",
                file_types=["image"],
                type="filepath",
            )

            with gr.Row():
                height = gr.Slider(512, 1536, value=1024, step=64, label="Chiều cao")
                width = gr.Slider(512, 1536, value=1024, step=64, label="Chiều rộng")

            with gr.Accordion("⚙️ Cài đặt nâng cao", open=False):
                guidance_scale = gr.Slider(1.0, 5.0, value=2.5, step=0.1,
                    label="Guidance Scale (cao = theo prompt hơn)")
                img_guidance_scale = gr.Slider(1.0, 3.0, value=1.6, step=0.1,
                    label="Image Guidance Scale (cao = giữ ảnh gốc hơn)")
                seed = gr.Slider(-1, 999999, value=-1, step=1, label="Seed (-1 = random)")
                max_input_image_size = gr.Slider(256, 1024, value=1024, step=64,
                    label="Max Input Image Size (giảm nếu OOM)")

            with gr.Row():
                run_btn = gr.Button("🚀 Tạo ảnh", variant="primary", size="lg")
                clear_btn = gr.Button("🗑️ Xóa")

            gr.Examples(
                examples=[
                    ["A cyberpunk city at night with neon lights reflecting on wet streets", None, 1024, 1024, 2.5, 1.6, -1, 1024],
                    ["A watercolor painting of a peaceful Japanese garden with cherry blossoms", None, 1024, 1024, 2.5, 1.6, -1, 1024],
                    ["Turn the person in <img><|image_1|></img> into a Viking warrior", None, 1024, 1024, 2.5, 1.6, -1, 1024],
                    ["Replace the background of <img><|image_1|></img> with a tropical beach sunset", None, 1024, 1024, 2.5, 1.6, -1, 1024],
                    ["Make <img><|image_1|></img> look like an oil painting by Van Gogh", None, 1024, 1024, 2.5, 1.6, -1, 1024],
                ],
                inputs=[prompt, input_images, height, width, guidance_scale, img_guidance_scale, seed, max_input_image_size],
            )

        with gr.Column(scale=1):
            output_image = gr.Image(type="pil", label="🖼️ Kết quả")
            status = gr.Textbox(label="Trạng thái", interactive=False)

    # Event handlers
    run_btn.click(
        fn=generate_image,
        inputs=[prompt, input_images, height, width, guidance_scale, img_guidance_scale, seed, max_input_image_size],
        outputs=[output_image, status],
    )

    clear_btn.click(
        fn=lambda: ("", None, 1024, 1024, 2.5, 1.6, -1, 1024, None, ""),
        inputs=[],
        outputs=[prompt, input_images, height, width, guidance_scale, img_guidance_scale, seed, max_input_image_size, output_image, status],
    )

# ============================================================
# LAUNCH — Public URL qua gradio.live
# ============================================================
demo.launch(share=True)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# ⏳ Đang load OmniGen-v1...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1748/4129091529.py in <cell line: 0>()
#       6 # ============================================================
#       7 print("⏳ Đang load OmniGen-v1...")
# ----> 8 pipe = OmniGenPipeline.from_pretrained(
#       9     "Shitao/OmniGen-v1",
#      10     offload_model=True,  # T4 16GB VRAM → cần offload để tránh OOM
#
# TypeError: OmniGenPipeline.from_pretrained() got an unexpected keyword argument 'offload_model'
